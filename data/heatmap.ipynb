# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 예시 분할표 데이터
data = [[5, 10, 15],
        [10, 15, 20]]

# seaborn을 이용한 히트맵 작성 (황색-녹색-청색 순으로 진해짐, YlGnBu)
sns.heatmap(data, cmap="YlGnBu", annot=True, fmt="d", cbar=False)
plt.show()
