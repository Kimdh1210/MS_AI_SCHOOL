# %%
import seaborn as sns
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt
titanic_df = pd.read_csv("titanic_data.csv")

# 이원분산분석 모델 생성
model = ols('Survived ~ C(Sex) + C(Pclass) + C(Sex):C(Pclass)', data=titanic_df)
model = model.fit()

# %%
# 이원분산분석 진행
anova_results = anova_lm(model, typ=2)

sns.catplot(data=titanic_df, x='Sex', y='Survived', hue='Pclass', kind='bar')
plt.show()
# Out:
# C:\Users\김동현\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
