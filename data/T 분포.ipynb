# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# T-분포의 주요 파라미터 : 자유도
dof = 10
t_values = np.random.standard_t(dof, 1000)

plt.hist(t_values, bins=20, alpha=0.5)
plt.show()
