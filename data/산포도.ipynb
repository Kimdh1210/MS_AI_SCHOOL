# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.normal(loc=0, scale=1, size=100)
# 두 변수 간에 상관관계를 설정하여 산포도가 직관적일 수 있도록 예시를 생성
y = x + np.random.normal(loc=0, scale=0.5, size=100)

#산포도 그리기
plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()
