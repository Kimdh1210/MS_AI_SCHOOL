# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# 카이제곱 분포의 주요 파라미터 : 자유도 (DOF)
dof = 5

random_var = np.random.chisquare(dof, size=1000)

plt.hist(random_var, bins=30, density=True, alpha=0.7)
plt.show()
