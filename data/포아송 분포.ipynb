# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# 포아송 분포의 주요 파라미터는 사건 발생 평균 횟수 lambda
lambda_param = 3

# 포아송 분포를 따르는 시뮬레이션 횟수
num_simulation = 1000
events = np.random.poisson(lambda_param, num_simulation)

plt.hist(events, bins=10, alpha=0.5)
plt.show()
