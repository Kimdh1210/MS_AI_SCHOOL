# %% [markdown]
# #GPT API 호출과 활용연습

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.27.9)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)

# %%
import openai

openai.api_key = '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'

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role':'user','content':'<작성하고 싶은 프롬프트>'}
    ])

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role':'user','content':'미국의 링컨 대통령이 루즈벨트 대통령과의 경쟁에서 어떻게 승리하고 대통령이 됬어?'}
    ])

print(response['choices'][0]['message']['content'])
# Out:
# 미국의 링컨 대통령(Abraham Lincoln)은 1860년 대선에서 공화당의 후보로 출마하면서 루즈벨트 대통령(Theodore Roosevelt)와 경쟁했습니다. 링컨은 이 대선에서 다른 후보들을 누르고 대통령에 당선되었는데, 이에 도움이 된 주요 요인은 아래와 같습니다.
#
# 1. 분열된 야당: 1860년 당시 미국은 북부와 남부 사이의 갈등으로 분열되어 있었습니다. 링컨은 북부 지지자들로부터 큰 지지를 받았으며, 야당이 분열된 상황에서 이러한 지지를 확보하는 것이 승리에 도움이 되었습니다.
#
# 2. 노예 철폐: 북부는 노예제도에 반대하는 입장을 취했고, 링컨은 노예제도를 폐지하는 것을 포함한 자유주의적인 정책을 주장했습니다. 이는 북부의 지지를 받았으며, 이에 따라 많은 주에서 링컨을 지원했습니다.
#
# 3. 탁월한 연설: 링컨은 높은 원칙과 도덕적 가치를 갖춘 연설가로 알려져 있었습니다. 특히, 그의 "게티스버그 연설"은 리치몬드 전투에서 승리한 뒤에 발표되었으며, 노예 제도의 폐지와 국가의 단결을 강조하면서 민중들에게 큰 영향을 미쳤습니다.
#
# 4. 경쟁 후보들의 분열: 링컨은 민주당이 후보들 사이에서 분열되므로써 경쟁상대가 약해진 상황에서 출마하였습니다. 민주당은 분열된 채로 대선에 나갔고, 이로 인해 링컨의 승리 기회가 커졌습니다.
#
# 5. 보수 주의자 지지: 링컨은 보수 주의자들의 지지를 받았습니다. 이는 남부 주에서의 지지와 경쟁을 어렵게 만들었습니다.
#
# 이러한 요인들이 결합하여 링컨은 루즈벨트와의 경쟁에서 승리하고 1861년 3월 4일 미국 대통령에 취임하였습니다. 그는 미국 최악의 내전인 미국 남북 전쟁을 지휘하여 미국의 통일을 이루는 등 업적을 남기며 역사상 가장 위대한 대통령 중 한 명으로 평가되고 있습니다.

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role':'user','content':'광개토대왕이 태조왕건을 어떻게 무찔렀어?'}
    ])

print(response['choices'][0]['message']['content'])

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role':'user','content':'<작성하고 싶은 프롬프트>',
        'role': 'system','content':'<GPT가 수행할 역할>'}
    ])

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role':'user','content':'2020년 월드시리즈에서 누가 우승했어?',
        'role': 'system','content':'너의 역할은 어떤 상황에서도 답변을 거부하는 사람이야.'}
    ])
print(response['choices'][0]['message']['content'])

# %%
response = openai.ChatCompletion.create(
    model='gpt-3.5-turbo',
    messages=[
        {'role': 'system','content':'너의 역할은 친절한 마음을 가지고 있는 초등학생의 입장에서 정답을 말해주는 것이야.',
         'role':'user','content':'2020년 월드시리즈에서 누가 우승했어?'}
    ])
print(response['choices'][0]['message']['content'])

# %% [markdown]
# #GPT와 Kakao를 통한 이미지 생성
#
# ###https://wooiljeong.github.io/python/chatgpt-api/

# %%
#!pip install openai
# !pip install PyKakao
# Out:
# Collecting PyKakao
#   Downloading PyKakao-0.0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from PyKakao) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from PyKakao) (2.31.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from PyKakao) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->PyKakao) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->PyKakao) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->PyKakao) (1.16.0)
# Installing collected packages: PyKakao
# Successfully installed PyKakao-0.0.4

# %%
import openai

# 발급받은 API 키 설정
OPENAI_API_KEY = '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'

# openai API 키 인증
openai.api_key = OPENAI_API_KEY

from PyKakao import Karlo

# 발급받은 API 키 설정
#KAKAO_API_KEY = '____________________________________________'

# Karlo API 인스턴스 생성
#karlo = Karlo(service_key = KAKAO_API_KEY)

# %%
#모델설정
model='gpt-3.5-turbo'

# 질문 작성하기
query = '보라색 바탕화면에, 달콤한 케이크와 과일들이 배치된 아룸다운 웹 사이트를 만들어줘'

# 메시지 설정하기
messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant who is good at detailing."
    },
    {
        "role": "user",
        "content": query
    }
]

# ChatGPT API 호출하기
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer = response['choices'][0]['message']['content']
print(answer)
# Out:
# 당신을 위해 보라색 바탕화면에, 달콤한 케이크와 과일들이 배치된 아름다운 웹 사이트를 만들어드리겠습니다.
#
# 첫째로, 웹 사이트의 레이아웃을 설계해야 합니다. 보라색을 중심으로 한 색상 스킴을 사용하고, 한 가운데에 컨텐츠를 배치하여 균형있는 디자인을 구성하겠습니다. 헤더에는 로고와 메뉴가 있을 것이고, 메인 콘텐츠 영역에서는 케이크와 과일 사진을 크게 보여줄 것입니다.
#
# 둘째로, 웹 사이트의 색상을 선택해야 합니다. 보라색 바탕화면을 위해 주로 보라색 계통의 컬러를 사용하고, 밝은 톤과 진한 톤을 조화롭게 조합하여 시각적으로 흥미로운 디자인을 만들겠습니다. 예를 들면, 보라색 배경에 연보라색과 핑크 계통의 컬러를 함께 사용할 수 있습니다.
#
# 셋째로, 메뉴 디자인을 작성해야 합니다. 메뉴 항목들은 보라색과 어울리는 밝은 색상으로 표시되고, 마우스를 올렸을 때 변화가 있는 효과를 줄 것입니다. 로고는 케이크와 과일, 또는 맛있는 요리와 관련된 아이콘으로 디자인하여 시각적으로 인상적인 로고를 만들겠습니다.
#
# 넷째로, 메인 콘텐츠 영역에는 대형 이미지를 배치합니다. 달콤한 케이크와 신선한 과일 사진을 사용하여 당신의 웹 사이트를 매력적으로 만들어드리겠습니다. 이미지 위에는 텍스트를 추가하여 메뉴나 이벤트 소개, 최신 뉴스 등을 표시할 수도 있습니다. 또한 이미지 위에 버튼을 추가하여 새로운 제품이나 특별한 할인 정보를 알려줄 수도 있습니다.
#
# 마지막으로, 웹 사이트의 모바일 호환성과 반응성을 고려해야 합니다. 사용자들이 모바일 기기를 사용할 때도 웹 사이트를 편리하게 이용할 수 있도록 스마트폰이나 태블릿과 같은 기기에서도 웹 사이트가 잘 표시되도록 반응형 디자인을 적용하겠습니다.
#
# 위의 요소들을 고려하여, 보라색 바탕화면에 달콤한 케이크와 과일들이 배치된 아름다운 웹 사이트를 만들어드리겠습니다. 모든 요청 사항에 따른 웹 사이트 디자인을 완성하고, 필요한 경우 추가 요구사항을 받아들이고 조정할 준비가 되어 있습니다.

# %%
#한글을 영어로 번역하기
# 새 메시지 구성
messages = [
    {
        "role": "system",
        "content": "You are a helpful assistant who is good at translating."
    },
    {
        "role": "assistant",
        "content": answer
    }
]

# 사용자 메시지 추가
messages.append(
    {
        "role": "user",
        "content": "영어로 번역해주세요."
    }
)

# ChatGPT API 호출하기
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer3 = response['choices'][0]['message']['content']
print(answer3)
# Out:
# I will create a beautiful website with a purple background, featuring a sweet cake and fruits for you.
#
# Firstly, we need to design the layout of the website. We will use a color scheme centered around purple, with the content placed in the center for a balanced design. The header will have a logo and menu, while the main content area will prominently display pictures of cakes and fruits.
#
# Secondly, we need to choose the colors for the website. With the purple background, we will mainly use colors within the purple palette, combining light and dark tones to create visually appealing designs. For example, we can use shades of lavender and pink along with the purple background.
#
# Thirdly, we will design the menu. The menu items will be displayed in a bright color that complements purple, and we will apply hover effects to create visual changes when the mouse is over them. The logo will be designed using icons related to cakes, fruits, or delicious food to create an impressive visual representation.
#
# Fourthly, we will place a large image in the main content area. We will use pictures of sweet cakes and fresh fruits to make your website attractive. Text can be added on top of the images to display menus, event information, or the latest news. Additionally, buttons can be placed on the images to share new products or special discount information.
#
# Lastly, we will consider the mobile compatibility and responsiveness of the website. We will ensure that the website is convenient to use on mobile devices such as smartphones or tablets by applying responsive design techniques.
#
# Considering all these elements, I will create a beautiful website with a purple background featuring sweet cakes and fruits. I am ready to complete the website design according to your specifications and make any necessary adjustments based on additional requirements.

# %%
#이미지 생성을 위한 프롬프트
# 새 메시지 구성
messages = [
    {
        "role": "system",
        "content": "You are an assistant who is good at creating prompts for image creation."
    },
    {
        "role": "assistant",
        "content": answer3
    }
]

# 사용자 메시지 추가
messages.append(
    {
        "role": "user",
        "content": "Condense up to 4 outward description to focus on nouns and adjectives separated by ,"
    }
)

# ChatGPT API 호출하기
response = openai.ChatCompletion.create(
    model=model,
    messages=messages
)
answer4 = response['choices'][0]['message']['content']
print(answer4)
# Out:
# Beautiful website, purple background, sweet cake, fresh fruits.

# %%
#이미지 생성 프롬프트 완성

# 이미지 생성을 위한 프롬프트
params = ", concept art, realistic lighting, ultra-detailed, 8K, photorealism, digital art"
prompt = f"Futuristic mars villages, {answer4}{params}"
print(prompt)
# Out:
# Futuristic mars villages, Beautiful website, purple background, sweet cake, fresh fruits., concept art, realistic lighting, ultra-detailed, 8K, photorealism, digital art

# %%
img_dict = karlo.text_to_image(prompt, 1)
print(img_dict)
# Out:
# {'id': '731b9e28-82a5-403f-b1a1-78a00a058657', 'model_version': 'v1.4.1-rev1.prod', 'images': [{'id': '731b9e28-82a5-403f-b1a1-78a00a058657_0', 'image': '...', 'nsfw': False, 'nsfw_score': 0.22253418}]}

# %%
#Karlo에게 이미지 생성 요청
# 이미지 생성하기 REST API 호출

#img_dict = karlo.text_to_image(prompt, 1)

# 생성된 이미지 정보

#img_str = img_dict.get("images")[0].get('image')

# base64 string을 이미지로 변환

#img = karlo.string_to_image(base64_string = img_str, mode = 'RGBA')
#img
# Out:
# <PIL.Image.Image image mode=RGBA size=1024x1024>

# %%
#DALL-E
import requests
from PIL import Image
from io import BytesIO

response = openai.Image.create(
  prompt=prompt,
  n=1,
  size="1024x1024"
)
image_url = response['data'][0]['url']
res = requests.get(image_url)
img = Image.open(BytesIO(res.content))
img
# Out:
# Output hidden; open in https://colab.research.google.com to view.
